# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
#
# Note: Here Exception class refers to the base class for all the exceptions.

# %% [markdown]
# Ans1. We have to use the Exception class while creating a Custom Exception because when we use Exception class in our Custom Class it inherits the in-built properties of the Exception class which enable our code to be more specific and readable for python and add that piece of code into the Exception class as an exception.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %% [markdown]
# Ans2.

# %%
import inspect

def tree_class(cls, indent=0):
    print('-' * indent, cls.__name__)
    for subclass in cls.__subclasses__():
        tree_class(subclass, indent + 1)

tree_class(BaseException)
# Out:
#  BaseException
# - Exception
# -- TypeError
# --- FloatOperation
# --- MultipartConversionError
# -- StopAsyncIteration
# -- StopIteration
# -- ImportError
# --- ModuleNotFoundError
# --- ZipImportError
# -- OSError
# --- ConnectionError
# ---- BrokenPipeError
# ---- ConnectionAbortedError
# ---- ConnectionRefusedError
# ---- ConnectionResetError
# ----- RemoteDisconnected
# --- BlockingIOError
# --- ChildProcessError
# --- FileExistsError
# --- FileNotFoundError
# --- IsADirectoryError
# --- NotADirectoryError
# --- InterruptedError
# ---- InterruptedSystemCall
# --- PermissionError
# --- ProcessLookupError
# --- TimeoutError
# --- UnsupportedOperation
# --- itimer_error
# --- herror
# --- gaierror
# --- SSLError
# ---- SSLCertVerificationError
# ---- SSLZeroReturnError
# ---- SSLWantWriteError
# ---- SSLWantReadError
# ---- SSLSyscallError
# ---- SSLEOFError
# --- Error
# ---- SameFileError
# --- SpecialFileError
# --- ExecError
# --- ReadError
# --- URLError
# ---- HTTPError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# Ans3. Errors related to arithmetic operations when any arithmetic operation fails it triggers ArithmeticError Class. For example ZeroDivisionError, FloatingPointError and OverFlowError.

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# Ans4. LookupError is used to find error in Exception class that are riased when any index error or key error occur on a piece of code

# %%
a = [34,23,343,53]
try:
    a[5]
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
Fruits = {"Apple" : 3, "Mango" : 5, "Banana" : 1, "Strawberry" : 2}
try:
    print(Fruits["Berry"])
except KeyError:
    print("KeyError")
# Out:
# KeyError

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# Ans5. ImportError is a error which occurs when a package within a package is not found or their is incorrect module name.
#
# ModuleNotFoundError occurs when a specific module is not found in a import statement.

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [markdown]
# Ans6. Best practices for Exception Handling in python are as follows:
#
#     1. To use always a specific exception
#
#     2. Print always a proper message
#
#     3. Always try to log your error
#
#     4. Try to avoid multiple exception handling
#
#     5. Document all the Error in proper file so that it can be used later
#
#     6. Cleanup all the resources used.
